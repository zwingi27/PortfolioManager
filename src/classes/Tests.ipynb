# %%
import pandas as pd
import numpy as np
import os

# %%
path = r"/Users/danielrosskopf/Documents/Familie/Daniel/01_Bank/Test.csv"

# %%
start=10
df = pd.read_csv(path,sep=";")
df.columns = [i[:-1] for i in df.columns]
df["Analyse-Fixkosten"]= [True if i == "ja" else False for i in df["Analyse-Fixkosten"]]
df["Betrag"] = [i[:-1] for i in df["Betrag"]]
df["Kontostand"] = [i[:-1] for i in df["Kontostand"]]
df["Analyse-Betrag"] = [i[:-1] for i in df["Analyse-Betrag"]]
df.index = range(start,start+df.shape[0])
df = df.reset_index()
df
# Out:
#     index     Datum                     Art      Betrag Kontostand  \
# 0      10  02.10.23    Condor Riester Rente    -140,00   8.943,93
# 1      11  02.10.23    Fitnesstudio: GetFit     -34,90   8.909,03
# 2      12  02.10.23                  Paypal     -67,49   8.841,54
# 3      13  02.10.23  Streaminganteil Tobias     -15,00   8.826,54
# 4      14  02.10.23   Gehalt Bäldleschwaige     132,96   8.959,50
# 5      15  04.10.23       Alte Leipziger BU     -59,87   8.899,63
# 6      16  05.10.23           Barclays Card    -472,74   8.426,89
# 7      17  10.10.23                  Paypal      -7,99   8.418,90
# 8      18  10.10.23                  Paypal     -12,99   8.405,91
# 9      19  11.10.23      Deutschland Ticket     -49,00   8.356,91
# 10     20  13.10.23        Scalable Capital    -700,00   7.656,91
# 11     21  26.10.23         Sparplan Daniel     -20,00   7.636,91
# 12     22  26.10.23          Trade Republic  -1.500,00   6.136,91
# ...
